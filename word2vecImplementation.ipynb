# %%
# !pip install gensim

# %%
import gensim

# %%
from gensim.models import Word2Vec, KeyedVectors

# %%
import gensim.downloader as api
model=api.load('word2vec-google-news-300')
vec_king=model['king']
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
vec_king=model['king']

model.most_similar('batman')
# Out:
# [('nolan', 0.574455976486206),
#  ('Batman', 0.5551455020904541),
#  ('spidey', 0.5511770844459534),
#  ('spiderman', 0.5303406715393066),
#  ('ponting', 0.5213491916656494),
#  ('jedi', 0.5127660036087036),
#  ('sehwag', 0.5088648796081543),
#  ('harry_potter', 0.5088120102882385),
#  ('ricky', 0.5018243193626404),
#  ('Caped_Crusader', 0.5010268092155457)]

# %%
model.similarity("football","sports")
# Out:
# 0.5927178

# %%
vec=model['spiderman']-model['man']+model['woman']
model.most_similar(vec)
# Out:
# [('spiderman', 0.8497884273529053),
#  ('kristen_stewart', 0.5543040037155151),
#  ('spidey', 0.5464676022529602),
#  ('miley_cyrus', 0.5455173850059509),
#  ('megan_fox', 0.5432578325271606),
#  ('angelina', 0.5389854311943054),
#  ('robert_pattinson', 0.5358076691627502),
#  ('tom_cruise', 0.5309821367263794),
#  ('emma_watson', 0.5291973948478699),
#  ('fairy_princess', 0.5241716504096985)]
